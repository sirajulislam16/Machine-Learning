# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../DataSets_File/EDA_file/bangladesh_student_performance_updated.csv')

# %%
df.info() # dataset er data gulo somporke info
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2018 entries, 0 to 2017
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2018 non-null   str
#  1   gender        2018 non-null   str
#  2   age           1983 non-null   float64
#  3   address       1983 non-null   str
#  4   famsize       2018 non-null   str
#  5   Pstatus       2018 non-null   str
#  6   M_Edu         2018 non-null   int64
#  7   F_Edu         2018 non-null   int64
#  8   M_Job         1983 non-null   str
#  9   F_Job         2018 non-null   str
#  10  relationship  2018 non-null   str
#  11  smoker        2018 non-null   str
#  12  tuition_fee   1983 non-null   float64
#  13  time_friends  2018 non-null   int64
#  14  ssc_result    2018 non-null   float64
#  15  hsc_result    2018 non-null   float64
# dtypes: float64(4), int64(3), str(9)
# memory usage: 340.4 KB

# %%
df.shape # (data, feature)
# Out:
# (2018, 16)

# %%
df.sample(10)
# Out:
#             date gender   age address famsize   Pstatus  M_Edu  F_Edu  \
# 928   29/04/2018      F  17.0   Urban     GT3  Together      3      4
# 786   29/04/2018      F  18.0   Urban     LE3  Together      0      3
# 825   29/04/2018      F  19.0   Urban     GT3     Apart      3      0
# 1396  29/04/2018      M  19.0   Rural     GT3  Together      2      3
# 1556  29/04/2018      F  17.0   Rural     GT3  Together      1      1
# 970   29/04/2018      F  19.0   Urban     GT3  Together      2      2
# 1013  29/04/2018      M  19.0   Urban     GT3  Together      0      3
# 1566  29/04/2018      F  19.0   Rural     GT3  Together      2      1
# 861   29/04/2018      M  18.0   Rural     GT3  Together      1      0
# 848   29/04/2018      M  18.0   Rural     GT3     Apart      2      2
#
#          M_Job     F_Job relationship smoker  tuition_fee  time_friends  \
# 928   Services  Services           No     No      83983.0             4
# ...

# %%
df.info() # dataset er data gulo somporke info
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2018 entries, 0 to 2017
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          2018 non-null   str
#  1   gender        2018 non-null   str
#  2   age           1983 non-null   float64
#  3   address       1983 non-null   str
#  4   famsize       2018 non-null   str
#  5   Pstatus       2018 non-null   str
#  6   M_Edu         2018 non-null   int64
#  7   F_Edu         2018 non-null   int64
#  8   M_Job         1983 non-null   str
#  9   F_Job         2018 non-null   str
#  10  relationship  2018 non-null   str
#  11  smoker        2018 non-null   str
#  12  tuition_fee   1983 non-null   float64
#  13  time_friends  2018 non-null   int64
#  14  ssc_result    2018 non-null   float64
#  15  hsc_result    2018 non-null   float64
# dtypes: float64(4), int64(3), str(9)
# memory usage: 340.4 KB

# %%
print(df['famsize'].unique())
print("\n")
print(df['time_friends'].unique())
print("\n")
print(df['M_Edu'].unique())
# Out:
# <ArrowStringArray>
# ['GT3', 'LE3']
# Length: 2, dtype: str
#
#
# [4 5 3 2 1]
#
#
# [3 0 2 1 4]

# %%
df.isnull().sum()
# Out:
# date             0
# gender           0
# age             35
# address         35
# famsize          0
# Pstatus          0
# M_Edu            0
# F_Edu            0
# M_Job           35
# F_Job            0
# relationship     0
# smoker           0
# tuition_fee     35
# time_friends     0
# ssc_result       0
# hsc_result       0
# dtype: int64

# %%
df.describe()
# Out:
#                age        M_Edu        F_Edu    tuition_fee  time_friends  \
# count  1983.000000  2018.000000  2018.000000    1983.000000    2018.00000
# mean     17.980837     1.871160     2.174430   73045.274332       3.05996
# std       0.825695     1.194206     1.252979   24102.016020       1.43919
# min      17.000000     0.000000     0.000000   25102.000000       1.00000
# 25%      17.000000     1.000000     1.000000   53639.500000       2.00000
# 50%      18.000000     2.000000     2.000000   71343.000000       3.00000
# 75%      19.000000     3.000000     3.000000   91185.000000       4.00000
# max      19.000000     4.000000     4.000000  129168.000000       5.00000
#
#         ssc_result   hsc_result
# count  2018.000000  2018.000000
# mean      3.788087     3.199177
# std       0.622376     0.604526
# min       2.000000     2.000000
# 25%       3.360000     2.780000
# 50%       3.770000     3.160000
# 75%       4.230000     3.580000
# max       5.000000     5.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Explotory Data Analysis (EDA)

# %% [markdown]
# ##### Visualizing the data helps us identify patterns, correlations between features, and potential outliers. We look at the distribution of numerical features and the relationship between our target variable (hsc_result) and other predictors.

# %%
# Check for duplicate rows in the dataset
print(f"Initial duplicate count: {df.duplicated().sum()}")

# If we had duplictaed value, we needed to drop this
df.drop_duplicates(inplace=True)

# Verify that duplicates have seen removed
print(f"Duplicate count after removal: {df.duplicated().sum()}")
# Out:
# Initial duplicate count: 0
# Duplicate count after removal: 0

# %%
# Generate histogram for all numerical features to visualize their distribution
# 'bins = 15' controls the number of bars, and 'fig size' sets the display dimensions

df.hist(bins=15, figsize=(14,10))
plt.suptitle('Distribution of Numerical Features')
plt.show()

# %%
numerical_col = ['age', 'tuition_fee', 'ssc_result', 'hsc_result']
df[numerical_col].corr()
# Out:
#                   age  tuition_fee  ssc_result  hsc_result
# age          1.000000     0.001015   -0.013061   -0.012592
# tuition_fee  0.001015     1.000000    0.018385    0.041205
# ssc_result  -0.013061     0.018385    1.000000    0.950178
# hsc_result  -0.012592     0.041205    0.950178    1.000000

# %%
# Create a heatmap to visualize the Pearson correlation coefficients between numerical columns
# 'annot=True' displays the correlation values on the map

plt.figure(figsize=(8,6))

sns.heatmap(
    df[numerical_col].corr(),
    annot= True, # eatmap-এর প্রতিটি ঘরের (cell) ভেতরে numerical value দেখা যায়।
    cmap= 'coolwarm' #color
)

plt.title("Correlation Heatmap of Numerical Columns")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap of Numerical Columns')

# %%
# Boxplot use kora hoy outlier detaction er jonno

sns.boxplot(data= df, x= "ssc_result")
# Out:
# <Axes: xlabel='ssc_result'>

# %%
sns.boxplot(data= df, x= "hsc_result")
# Out:
# <Axes: xlabel='hsc_result'>

# %%
sns.boxplot(data= df, x= "age")
# Out:
# <Axes: xlabel='age'>

# %%
sns.boxplot(data= df, x= "tuition_fee")
# Out:
# <Axes: xlabel='tuition_fee'>
